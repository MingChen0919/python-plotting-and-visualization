# %% [markdown]
# ---
# # Errorbar
# ---

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data

# %%
x1 = np.arange(20)
y1 = np.random.randn(len(x)) + 5
yerr1 = np.random.randn(len(x1))

x2 = np.arange(21, 41)
y2 = np.random.randn(len(x)) + 5
yerr2 = np.random.randn(len(x2))

# %%
fig, sp = plt.subplots(nrows=1, ncols=1, figsize=(12,5))
eb1 = sp.errorbar(x1, y1, yerr1, color='blue', capsize=5)
eb1.set_label('Errorbar 1')


eb2 = sp.errorbar(x2, y2, yerr2, color='red', capsize=5, ecolor='blue')
eb2.set_label('Errorbar 2')

sp.legend()
sp.set_xlabel('X')
sp.set_ylabel('Error')
sp.set_title('Plotting error bar')

plt.show()
